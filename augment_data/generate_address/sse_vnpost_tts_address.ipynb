# %%
import sys
sys.path.append("/home/nampv1/projects/tts/speech-synth-engine")

# %%
from speech_synth_engine.providers.vnpost_provider import VnPostTTSProvider
from speech_synth_engine.providers.gtts_provider import GTTSProvider

# %%
# Khởi tạo provider
vnpost = VnPostTTSProvider()

# Sử dụng
vnpost.synthesize(
    text="Xin chào, đây là giọng nói tổng hợp được sinh ra từ VnPost TTS",
    voice="Hà My",
    output_file="synthesized_output.wav"
)
# Out:
# ✅ Đã tạo audio từ VnPost TTS: synthesized_output.wav

# %%
gtts = GTTSProvider()

gtts.synthesize(
    text="Xin chào, đây là giọng nói tổng hợp được sinh ra từ VnPost TTS",
    voice="Hà My",
    output_file="gtts_synthesized_output.wav"
)
# Out:
# ✅ Đã tạo audio từ gTTS: gtts_synthesized_output.wav
