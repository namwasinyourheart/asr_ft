# %%
cd /mnt/prj-vol
# Out:
# /__modal/volumes/vo-avs6pCgUGdIH1rstyYfAO1

# %%
# !git clone https://github.com/namwasinyourheart/asr_ft.git
# Out:
# Cloning into 'asr_ft'...
# remote: Enumerating objects: 505, done.
# remote: Counting objects: 100% (505/505), done.
# remote: Compressing objects: 100% (283/283), done.
# remote: Total 505 (delta 272), reused 443 (delta 210), pack-reused 0 (from 0)
# Receiving objects: 100% (505/505), 5.51 MiB | 7.63 MiB/s, done.
# Resolving deltas: 100% (272/272), done.

# %%
cd asr_ft
# Out:
# /__modal/volumes/vo-avs6pCgUGdIH1rstyYfAO1/asr_ft

# %%
ls
# Out:
# configs/            eval.py      notebooks/        src/
# download_data.py    examples/    prepare_data.py   transcribe.py
# download_models.py  finetune.py  requirements.txt

# %%
import os
os.environ['HF_HOME'] = "/mnt/models-vol/cache_huggingface"

# %%
# !echo $HF_HOME
# Out:
# /mnt/models-vol/cache_huggingface

# %%
# !apt-get install ffmpeg -y
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   alsa-topology-conf alsa-ucm-conf fontconfig i965-va-driver intel-media-va-driver libaacs0 libasound2
#   libasound2-data libass9 libasyncns0 libavc1394-0 libavcodec59 libavdevice59 libavfilter8 libavformat59
#   libavutil57 libbdplus0 libblas3 libbluray2 libbs2b0 libcaca0 libcairo-gobject2 libcairo2 libcdio-cdda2
#   libcdio-paranoia2 libcdio19 libchromaprint1 libcjson1 libcodec2-1.0 libdatrie1 libdc1394-25 libdecor-0-0
#   libdecor-0-plugin-1-cairo libdrm-amdgpu1 libdrm-common libdrm-intel1 libdrm-nouveau2 libdrm-radeon1 libdrm2
#   libelf1 libepoxy0 libflac12 libflite1 libfribidi0 libgbm1 libgdk-pixbuf-2.0-0 libgdk-pixbuf2.0-bin
#   libgdk-pixbuf2.0-common libgl1 libgl1-mesa-dri libglapi-mesa libglib2.0-0 libglib2.0-data libglvnd0
# ...

# %%
# %uv pip install -r requirements.txt
# Out:
# Using Python 3.12.6 environment at: /usr/local
# Updating https://github.com/huggingface/transformers (HEAD)
# Updating https://github.com/huggingface/transformers (HEAD)
# Updating https://github.com/huggingface/transformers (HEAD)
# Updating https://github.com/huggingface/transformers (HEAD)
# Updating https://github.com/huggingface/transformers (HEAD)
# Updating https://github.com/huggingface/transformers (HEAD)
# Updating https://github.com/huggingface/transformers (HEAD)
# Updating https://github.com/huggingface/transformers (HEAD)
# Updating https://github.com/huggingface/transformers (HEAD)
# Updating https://github.com/huggingface/transformers (HEAD)
# Updating https://github.com/huggingface/transformers (HEAD)
# Updating https://github.com/huggingface/transformers (HEAD)
# Updating https://github.com/huggingface/transformers (HEAD)
# Updating https://github.com/huggingface/transformers (HEAD)
# Updating https://github.com/huggingface/transformers (HEAD)
# ...

# %%
# !python download_data.py  \
    --data_root="/mnt/data-vol/vnpost-asr"
# Out:
# 0it [00:00, ?it/s]Downloading dataset nguyendv02/ViMD_Dataset...
#
# README.md: 7.43kB [00:00, 12.6MB/s]
# Repo card metadata block was not found. Setting CardData to empty.
#
# ...
# Resolving data files: 100%|██████████████████| 103/103 [00:00<00:00, 255.81it/s]
#
# ...
#
# data/train-00000-of-00103.parquet:   0%|             | 0.00/408M [00:00<?, ?B/s]
#
# data/train-00000-of-00103.parquet:   0%| | 10.4k/408M [00:00<10:22:46, 10.9kB/s]
#
# data/train-00000-of-00103.parquet:   1%|    | 5.36M/408M [00:01<01:28, 4.53MB/s]
#
# data/train-00000-of-00103.parquet:  18%|▋   | 72.4M/408M [00:02<00:10, 33.1MB/s]
#
# data/train-00000-of-00103.parquet:  34%|█▋   | 139M/408M [00:03<00:04, 59.2MB/s]
#
# data/train-00000-of-00103.parquet:  51%|██▌  | 206M/408M [00:03<00:02, 90.4MB/s]
#
# data/train-00000-of-00103.parquet:  67%|████  | 273M/408M [00:03<00:01, 125MB/s]
#
# data/train-00000-of-00103.parquet: 100%|██████| 408M/408M [00:04<00:00, 101MB/s]
#
# ...
#
# ...
