# %%
import os
os.environ['HF_HOME'] = "/mnt/models-vol/cache_huggingface"

# %%
# !echo $HF_HOME
# Out:
# /mnt/models-vol/cache_huggingface

# %%
models_list = [
    "openai/whisper-large-v3-turbo",
    "openai/whisper-large-v3",
    "vinai/phowhisper-large",
    "erax-ai/EraX-WoW-Turbo-V1.0"
]


from huggingface_hub import snapshot_download
from tqdm import tqdm

for model in tqdm(models_list):

    print(f"Download model {model}...")

    snapshot_dir = snapshot_download(
        repo_id=model,
        revision="main",      
        # cache_dir="/mnt/models-vol/huggingface"
    )
# Out:
#   0%|                                                                                    | 0/4 [00:00<?, ?it/s]
# Download model openai/whisper-large-v3-turbo...
# Fetching 13 files:   0%|          | 0/13 [00:00<?, ?it/s]
# normalizer.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# added_tokens.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/1.62G [00:00<?, ?B/s]
# generation_config.json: 0.00B [00:00, ?B/s]
# config.json: 0.00B [00:00, ?B/s]
# .gitattributes: 0.00B [00:00, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json: 0.00B [00:00, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/340 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
#  25%|███████████████████                                                         | 1/4 [00:12<00:37, 12.42s/it]
# Download model openai/whisper-large-v3...
# Fetching 21 files:   0%|          | 0/21 [00:00<?, ?it/s]
# flax_model.msgpack:   0%|          | 0.00/6.17G [00:00<?, ?B/s]
# model.fp32-00001-of-00002.safetensors:   0%|          | 0.00/4.99G [00:00<?, ?B/s]
# pytorch_model.fp32-00002-of-00002.bin:   0%|          | 0.00/1.18G [00:00<?, ?B/s]
# pytorch_model.fp32-00001-of-00002.bin:   0%|          | 0.00/4.99G [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/3.09G [00:00<?, ?B/s]
# model.fp32-00002-of-00002.safetensors:   0%|          | 0.00/1.18G [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/3.09G [00:00<?, ?B/s]
#  50%|█████████████████████████████████████▌                                     | 2/4 [04:03<04:41, 140.97s/it]
# Download model vinai/phowhisper-large...
# Fetching 13 files:   0%|          | 0/13 [00:00<?, ?it/s]
# generation_config.json: 0.00B [00:00, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# .gitattributes: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# config.json: 0.00B [00:00, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/339 [00:00<?, ?B/s]
# added_tokens.json: 0.00B [00:00, ?B/s]
# normalizer.json: 0.00B [00:00, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/805 [00:00<?, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json: 0.00B [00:00, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/6.17G [00:00<?, ?B/s]
#  75%|█████████████████████████████████████████████████████████                   | 3/4 [04:45<01:35, 95.87s/it]
# Download model erax-ai/EraX-WoW-Turbo-V1.0...
# Fetching 12 files:   0%|          | 0/12 [00:00<?, ?it/s]
# .gitattributes: 0.00B [00:00, ?B/s]
# generation_config.json: 0.00B [00:00, ?B/s]
# normalizer.json: 0.00B [00:00, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# config.json: 0.00B [00:00, ?B/s]
# added_tokens.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/1.62G [00:00<?, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/357 [00:00<?, ?B/s]
# special_tokens_map.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# 100%|████████████████████████████████████████████████████████████████████████████| 4/4 [05:00<00:00, 75.00s/it]
