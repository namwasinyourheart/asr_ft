# %%
cd /mnt/prj-vol/
# Out:
# /__modal/volumes/vo-lwZWPDBHpTCl13LS9ZlseR

# %%
# !git clone https://github.com/namwasinyourheart/asr_ft.git

# %%
cd asr_ft
# Out:
# /__modal/volumes/vo-lwZWPDBHpTCl13LS9ZlseR/asr_ft

# %%
pwd
# Out:
# '/__modal/volumes/vo-lwZWPDBHpTCl13LS9ZlseR/asr_ft'

# %%
ls
# Out:
# configs/            eval.py      notebooks/        src/
# download_data.py    examples/    prepare_data.py   summarize_results.py
# download_models.py  finetune.py  requirements.txt  transcribe.py

# %%
# !git pull origin main
# Out:
# remote: Enumerating objects: 7, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 5 (delta 2), reused 5 (delta 2), pack-reused 0 (from 0)
# Unpacking objects: 100% (5/5), 1.52 KiB | 222.00 KiB/s, done.
# From https://github.com/namwasinyourheart/asr_ft
#  * branch            main       -> FETCH_HEAD
#    8c113e5..8ad523e  main       -> origin/main
# Updating 8c113e5..8ad523e
# Fast-forward
#  configs/03092025/openai_whisper-large-v3-turbo__vimd.yaml | 120 ++++++++++++++++++++++++++++++++++++++++++++++
#  1 file changed, 120 insertions(+)
#  create mode 100644 configs/03092025/openai_whisper-large-v3-turbo__vimd.yaml

# %%
import os
os.environ['HF_HOME'] = "/mnt/models-vol/cache_huggingface"

# %%
# !echo $HF_HOME
# Out:
# /mnt/models-vol/cache_huggingface

# %%
# !apt-get install ffmpeg -y
# %uv pip install -r requirements.txt
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# ffmpeg is already the newest version (7:5.1.7-0+deb12u1).
# 0 upgraded, 0 newly installed, 0 to remove and 50 not upgraded.
# Using Python 3.12.6 environment at: /usr/local
# Updating https://github.com/huggingface/transformers (HEAD)
# Updating https://github.com/huggingface/transformers (HEAD)
# Updating https://github.com/huggingface/transformers (HEAD)
# Updating https://github.com/huggingface/transformers (HEAD)
# Updating https://github.com/huggingface/transformers (HEAD)
# Updating https://github.com/huggingface/transformers (HEAD)
# Updating https://github.com/huggingface/transformers (HEAD)
# Updating https://github.com/huggingface/transformers (HEAD)
# Updating https://github.com/huggingface/transformers (HEAD)
# Updating https://github.com/huggingface/transformers (HEAD)
# Updating https://github.com/huggingface/transformers (HEAD)
# Updating https://github.com/huggingface/transformers (HEAD)
# Updating https://github.com/huggingface/transformers (HEAD)
# Updating https://github.com/huggingface/transformers (HEAD)
# Updating https://github.com/huggingface/transformers (HEAD)
# Updating https://github.com/huggingface/transformers (HEAD)
# Updating https://github.com/huggingface/transformers (HEAD)
# Updating https://github.com/huggingface/transformers (HEAD)
# Updating https://github.com/huggingface/transformers (HEAD)
# Updating https://github.com/huggingface/transformers (HEAD)
# Updating https://github.com/huggingface/transformers (HEAD)
# Updating https://github.com/huggingface/transformers (HEAD)
# Updating https://github.com/huggingface/transformers (HEAD)
# Updating https://github.com/huggingface/transformers (HEAD)
# Updating https://github.com/huggingface/transformers (HEAD)
# Updating https://github.com/huggingface/transformers (HEAD)
# Updating https://github.com/huggingface/transformers (HEAD)
# Updating https://github.com/huggingface/transformers (HEAD)
# Updating https://github.com/huggingface/transformers (HEAD)
# Updating https://github.com/huggingface/transformers (HEAD)
# Updating https://github.com/huggingface/transformers (HEAD)
# Updating https://github.com/huggingface/transformers (HEAD)
# Updating https://github.com/huggingface/transformers (HEAD)
# Updating https://github.com/huggingface/transformers (HEAD)
# Updating https://github.com/huggingface/transformers (HEAD)
# Updating https://github.com/huggingface/transformers (HEAD)
# Updating https://github.com/huggingface/transformers (HEAD)
# Updating https://github.com/huggingface/transformers (HEAD)
# Updating https://github.com/huggingface/transformers (HEAD)
# Updating https://github.com/huggingface/transformers (HEAD)
# Updating https://github.com/huggingface/transformers (HEAD)
# Updating https://github.com/huggingface/transformers (HEAD)
# Updating https://github.com/huggingface/transformers (HEAD)
# Updating https://github.com/huggingface/transformers (HEAD)
# Updating https://github.com/huggingface/transformers (HEAD)
# Updating https://github.com/huggingface/transformers (HEAD)
# Updating https://github.com/huggingface/transformers (HEAD)
# Updating https://github.com/huggingface/transformers (HEAD)
# Updating https://github.com/huggingface/transformers (HEAD)
# Updating https://github.com/huggingface/transformers (HEAD)
# Updating https://github.com/huggingface/transformers (HEAD)
# Updating https://github.com/huggingface/transformers (HEAD)
# Updating https://github.com/huggingface/transformers (HEAD)
# Updating https://github.com/huggingface/transformers (HEAD)
# Updating https://github.com/huggingface/transformers (HEAD)
# Updating https://github.com/huggingface/transformers (HEAD)
# Updating https://github.com/huggingface/transformers (HEAD)
# Updating https://github.com/huggingface/transformers (HEAD)
# Updating https://github.com/huggingface/transformers (HEAD)
# Updating https://github.com/huggingface/transformers (HEAD)
# Updating https://github.com/huggingface/transformers (HEAD)
# Updating https://github.com/huggingface/transformers (HEAD)
# Updating https://github.com/huggingface/transformers (HEAD)
# Updating https://github.com/huggingface/transformers (HEAD)
# Updating https://github.com/huggingface/transformers (HEAD)
# Updating https://github.com/huggingface/transformers (HEAD)
# Updating https://github.com/huggingface/transformers (HEAD)
# Updating https://github.com/huggingface/transformers (HEAD)
# Updating https://github.com/huggingface/transformers (HEAD)
# Updating https://github.com/huggingface/transformers (HEAD)
# Updating https://github.com/huggingface/transformers (HEAD)
# Updating https://github.com/huggingface/transformers (HEAD)
# Updating https://github.com/huggingface/transformers (HEAD)
# Updating https://github.com/huggingface/transformers (HEAD)
# Updating https://github.com/huggingface/transformers (HEAD)
# Updating https://github.com/huggingface/transformers (HEAD)
# Updating https://github.com/huggingface/transformers (HEAD)
# Updating https://github.com/huggingface/transformers (HEAD)
# Updating https://github.com/huggingface/transformers (HEAD)
# Updating https://github.com/huggingface/transformers (HEAD)
# Updating https://github.com/huggingface/transformers (HEAD)
# Updating https://github.com/huggingface/transformers (HEAD)
# Updating https://github.com/huggingface/transformers (HEAD)
# Updating https://github.com/huggingface/transformers (HEAD)
# Updating https://github.com/huggingface/transformers (HEAD)
# Updating https://github.com/huggingface/transformers (HEAD)
# Updating https://github.com/huggingface/transformers (HEAD)
# Updating https://github.com/huggingface/transformers (HEAD)
# Updating https://github.com/huggingface/transformers (HEAD)
# Updating https://github.com/huggingface/transformers (HEAD)
# Updating https://github.com/huggingface/transformers (HEAD)
# Updating https://github.com/huggingface/transformers (HEAD)
# Updating https://github.com/huggingface/transformers (HEAD)
# Updating https://github.com/huggingface/transformers (HEAD)
# Updating https://github.com/huggingface/transformers (HEAD)
# Updating https://github.com/huggingface/transformers (HEAD)
# Updating https://github.com/huggingface/transformers (HEAD)
# Updating https://github.com/huggingface/transformers (HEAD)
#  Updated https://github.com/huggingface/transformers (0f5e45a6d)
# Resolved 117 packages in 24.12s
# Building antlr4-python3-runtime==4.9.3
# Building antlr4-python3-runtime==4.9.3
# Building rouge-score==0.1.2
# Building antlr4-python3-runtime==4.9.3
# Building rouge-score==0.1.2
# ⠙ Preparing packages... (0/43)
# Building antlr4-python3-runtime==4.9.3
# Building rouge-score==0.1.2
# ⠙ Preparing packages... (0/43)
# Building antlr4-python3-runtime==4.9.3
# Building rouge-score==0.1.2
# ⠙ Preparing packages... (0/43)
# setproctitle ------------------------------     0 B/31.00 KiB
# Building antlr4-python3-runtime==4.9.3
# Building rouge-score==0.1.2
# ⠙ Preparing packages... (0/43)
# setproctitle ------------------------------ 14.91 KiB/31.00 KiB
# Building antlr4-python3-runtime==4.9.3
# Building rouge-score==0.1.2
# ⠙ Preparing packages... (0/43)
# colorama   ------------------------------     0 B/24.74 KiB
# setproctitle ------------------------------ 14.91 KiB/31.00 KiB
# Building antlr4-python3-runtime==4.9.3
# Building rouge-score==0.1.2
# ⠙ Preparing packages... (0/43)
# colorama   ------------------------------ 14.84 KiB/24.74 KiB
# setproctitle ------------------------------ 14.91 KiB/31.00 KiB
# Building antlr4-python3-runtime==4.9.3
# Building rouge-score==0.1.2
# ⠙ Preparing packages... (0/43)
# smmap      ------------------------------     0 B/23.73 KiB
# colorama   ------------------------------ 14.84 KiB/24.74 KiB
# setproctitle ------------------------------ 14.91 KiB/31.00 KiB
# Building antlr4-python3-runtime==4.9.3
# Building rouge-score==0.1.2
# ⠙ Preparing packages... (0/43)
# smmap      ------------------------------ 14.88 KiB/23.73 KiB
# colorama   ------------------------------ 14.84 KiB/24.74 KiB
# setproctitle ------------------------------ 14.91 KiB/31.00 KiB
# Building antlr4-python3-runtime==4.9.3
# Building rouge-score==0.1.2
# ⠙ Preparing packages... (0/43)
# audioread  ------------------------------     0 B/22.94 KiB
# smmap      ------------------------------ 14.88 KiB/23.73 KiB
# colorama   ------------------------------ 14.84 KiB/24.74 KiB
# setproctitle ------------------------------ 14.91 KiB/31.00 KiB
# Building antlr4-python3-runtime==4.9.3
# Building rouge-score==0.1.2
# ⠙ Preparing packages... (0/43)
# audioread  ------------------------------ 14.93 KiB/22.94 KiB
# smmap      ------------------------------ 14.88 KiB/23.73 KiB
# colorama   ------------------------------ 14.84 KiB/24.74 KiB
# setproctitle ------------------------------ 14.91 KiB/31.00 KiB
# Building antlr4-python3-runtime==4.9.3
# Building rouge-score==0.1.2
# ⠙ Preparing packages... (0/43)
# jiwer      ------------------------------     0 B/22.49 KiB
# audioread  ------------------------------ 14.93 KiB/22.94 KiB
# smmap      ------------------------------ 14.88 KiB/23.73 KiB
# colorama   ------------------------------ 14.84 KiB/24.74 KiB
# setproctitle ------------------------------ 14.91 KiB/31.00 KiB
# Building antlr4-python3-runtime==4.9.3
# Building rouge-score==0.1.2
# ⠙ Preparing packages... (0/43)
# jiwer      ------------------------------ 14.92 KiB/22.49 KiB
# audioread  ------------------------------ 14.93 KiB/22.94 KiB
# smmap      ------------------------------ 14.88 KiB/23.73 KiB
# colorama   ------------------------------ 14.84 KiB/24.74 KiB
KiB
# Building antlr4-python3-runtime==4.9.3
# Building rouge-score==0.1.2
# Building transformers @ git+https://github.com/huggingface/transformers@0f5e45a6d1ed
# ⠙ Preparing packages... (0/43)
# docker-pycreds ------------------------------ 8.77 KiB/8.77 KiB
# texttable  ------------------------------ 10.52 KiB/10.52 KiB
# multivolumefile ------------------------------ 16.64 KiB/16.64 KiB
# python-dotenv ------------------------------ 14.92 KiB/19.40 KiB
# jiwer      ------------------------------ 14.92 KiB/22.49 KiB
# audioread  ------------------------------ 14.93 KiB/22.94 KiB
# smmap      ------------------------------ 14.88 KiB/23.73 KiB
# colorama   ------------------------------ 14.84 KiB/24.74 KiB
# setproctitle ------------------------------ 31.00 KiB/31.00 KiB
# pybcj      ------------------------------ 46.91 KiB/50.46 KiB
# gitdb      ------------------------------ 30.91 KiB/61.32 KiB
# pooch      ------------------------------ 30.92 KiB/63.06 KiB
# py7zr      ------------------------------ 30.92 KiB/66.31 KiB
# omegaconf  ------------------------------ 30.85 KiB/77.64 KiB
# evaluate   ------------------------------ 30.91 KiB/82.13 KiB
# inflate64  ------------------------------ 94.76 KiB/94.76 KiB
# dill       ------------------------------ 46.93 KiB/113.53 KiB
# pyppmd     ------------------------------ 139.48 KiB/139.48 KiB
# Building antlr4-python3-runtime==4.9.3
# Building rouge-score==0.1.2
# Building transformers @ git+https://github.com/huggingface/transformers@0f5e45a6d1ed
# ⠙ Preparing packages... (0/43)
# docker-pycreds ------------------------------ 8.77 KiB/8.77 KiB
# texttable  ------------------------------ 10.52 KiB/10.52 KiB
# multivolumefile ------------------------------ 16.64 KiB/16.64 KiB
# python-dotenv ------------------------------ 14.92 KiB/19.40 KiB
# jiwer      ------------------------------ 22.49 KiB/22.49 KiB
# audioread  ------------------------------ 22.94 KiB/22.94 KiB
# smmap      ------------------------------ 14.88 KiB/23.73 KiB
# colorama   ------------------------------ 14.84 KiB/24.74 KiB
# setproctitle ------------------------------ 31.00 KiB/31.00 KiB
# pybcj      ------------------------------ 46.91 KiB/50.46 KiB
# gitdb      ------------------------------ 30.91 KiB/61.32 KiB
# pooch      ------------------------------ 30.92 KiB/63.06 KiB
# py7zr      ------------------------------ 30.92 KiB/66.31 KiB
# omegaconf  ------------------------------ 46.85 KiB/77.64 KiB
# evaluate   ------------------------------ 30.91 KiB/82.13 KiB
# inflate64  ------------------------------ 94.76 KiB/94.76 KiB
# dill       ------------------------------ 46.93 KiB/113.53 KiB
# pyppmd     ------------------------------ 139.48 KiB/139.48 KiB
# Building antlr4-python3-runtime==4.9.3
# Building rouge-score==0.1.2
# Building transformers @ git+https://github.com/huggingface/transformers@0f5e45a6d1ed
# ⠙ Preparing packages... (0/43)
# docker-pycreds ------------------------------ 8.77 KiB/8.77 KiB
# multivolumefile ------------------------------ 16.64 KiB/16.64 KiB
# python-dotenv ------------------------------ 14.92 KiB/19.40 KiB
# jiwer      ------------------------------ 22.49 KiB/22.49 KiB
# audioread  ------------------------------ 22.94 KiB/22.94 KiB
# smmap      ------------------------------ 14.88 KiB/23.73 KiB
# colorama   ------------------------------ 14.84 KiB/24.74 KiB
# setproctitle ------------------------------ 31.00 KiB/31.00 KiB
# pybcj      ------------------------------ 46.91 KiB/50.46 KiB
# gitdb      ------------------------------ 30.91 KiB/61.32 KiB
# pooch      ------------------------------ 30.92 KiB/63.06 KiB
# py7zr      ------------------------------ 30.92 KiB/66.31 KiB
# omegaconf  ------------------------------ 46.85 KiB/77.64 KiB
# evaluate   ------------------------------ 30.91 KiB/82.13 KiB
# inflate64  ------------------------------ 94.76 KiB/94.76 KiB
# dill       ------------------------------ 46.93 KiB/113.53 KiB
# pyppmd     ------------------------------ 139.48 KiB/139.48 KiB
# multiprocess ------------------------------ 32.00 KiB/143.30 KiB
# Building antlr4-python3-runtime==4.9.3
# Building rouge-score==0.1.2
# Building transformers @ git+https://github.com/huggingface/transformers@0f5e45a6d1ed
# ⠙ Preparing packages... (0/43)
# docker-pycreds ------------------------------ 8.77 KiB/8.77 KiB
# multivolumefile ------------------------------ 16.64 KiB/16.64 KiB
# python-dotenv ------------------------------ 14.92 KiB/19.40 KiB
# jiwer      ------------------------------ 22.49 KiB/22.49 KiB
# audioread  ------------------------------ 22.94 KiB/22.94 KiB
# smmap      ------------------------------ 23.73 KiB/23.73 KiB
# colorama   ------------------------------ 14.84 KiB/24.74 KiB
KiB
# Building antlr4-python3-runtime==4.9.3
# Building rouge-score==0.1.2
# Building transformers @ git+https://github.com/huggingface/transformers@0f5e45a6d1ed
# ⠹ Preparing packages... (3/43)
# docker-pycreds ------------------------------ 8.77 KiB/8.77 KiB
# python-dotenv ------------------------------ 19.40 KiB/19.40 KiB
# jiwer      ------------------------------ 22.49 KiB/22.49 KiB
# audioread  ------------------------------ 22.94 KiB/22.94 KiB
# smmap      ------------------------------ 23.73 KiB/23.73 KiB
# colorama   ------------------------------ 14.84 KiB/24.74 KiB
# gitdb      ------------------------------ 46.91 KiB/61.32 KiB
# pooch      ------------------------------ 46.92 KiB/63.06 KiB
# py7zr      ------------------------------ 46.92 KiB/66.31 KiB
# omegaconf  ------------------------------ 62.85 KiB/77.64 KiB
# evaluate   ------------------------------ 30.91 KiB/82.13 KiB
# dill       ------------------------------ 62.93 KiB/113.53 KiB
# pyppmd     ------------------------------ 139.48 KiB/139.48 KiB
# multiprocess ------------------------------ 48.00 KiB/143.30 KiB
# hydra-core ------------------------------ 14.84 KiB/150.92 KiB
# xxhash     ------------------------------ 189.82 KiB/189.82 KiB
# gitpython  ------------------------------ 76.17 KiB/203.29 KiB
# soxr       ------------------------------ 25.59 KiB/242.63 KiB
# Building antlr4-python3-runtime==4.9.3
# Building rouge-score==0.1.2
# Building transformers @ git+https://github.com/huggingface/transformers@0f5e45a6d1ed
# ⠹ Preparing packages... (3/43)
# python-dotenv ------------------------------ 19.40 KiB/19.40 KiB
# jiwer      ------------------------------ 22.49 KiB/22.49 KiB
# audioread  ------------------------------ 22.94 KiB/22.94 KiB
# smmap      ------------------------------ 23.73 KiB/23.73 KiB
# colorama   ------------------------------ 14.84 KiB/24.74 KiB
# gitdb      ------------------------------ 46.91 KiB/61.32 KiB
# pooch      ------------------------------ 46.92 KiB/63.06 KiB
# py7zr      ------------------------------ 46.92 KiB/66.31 KiB
# omegaconf  ------------------------------ 62.85 KiB/77.64 KiB
# evaluate   ------------------------------ 46.91 KiB/82.13 KiB
# dill       ------------------------------ 62.93 KiB/113.53 KiB
# pyppmd     ------------------------------ 139.48 KiB/139.48 KiB
# multiprocess ------------------------------ 48.00 KiB/143.30 KiB
# hydra-core ------------------------------ 14.84 KiB/150.92 KiB
# xxhash     ------------------------------ 189.82 KiB/189.82 KiB
# gitpython  ------------------------------ 76.17 KiB/203.29 KiB
# soxr       ------------------------------ 25.59 KiB/242.63 KiB
# librosa    ------------------------------ 80.00 KiB/254.64 KiB
# Building antlr4-python3-runtime==4.9.3
# Building rouge-score==0.1.2
# Building transformers @ git+https://github.com/huggingface/transformers@0f5e45a6d1ed
# ⠹ Preparing packages... (3/43)
# python-dotenv ------------------------------ 19.40 KiB/19.40 KiB
# jiwer      ------------------------------ 22.49 KiB/22.49 KiB
# audioread  ------------------------------ 22.94 KiB/22.94 KiB
# smmap      ------------------------------ 23.73 KiB/23.73 KiB
# colorama   ------------------------------ 14.84 KiB/24.74 KiB
# gitdb      ------------------------------ 46.91 KiB/61.32 KiB
# pooch      ------------------------------ 46.92 KiB/63.06 KiB
# py7zr      ------------------------------ 46.92 KiB/66.31 KiB
# omegaconf  ------------------------------ 62.85 KiB/77.64 KiB
# evaluate   ------------------------------ 46.91 KiB/82.13 KiB
# dill       ------------------------------ 62.93 KiB/113.53 KiB
# pyppmd     ------------------------------ 139.48 KiB/139.48 KiB
# multiprocess ------------------------------ 48.00 KiB/143.30 KiB
# hydra-core ------------------------------ 14.84 KiB/150.92 KiB
# gitpython  ------------------------------ 76.17 KiB/203.29 KiB
# soxr       ------------------------------ 25.59 KiB/242.63 KiB
# librosa    ------------------------------ 80.00 KiB/254.64 KiB
# trl        ------------------------------ 32.00 KiB/306.50 KiB
# Building antlr4-python3-runtime==4.9.3
# Building rouge-score==0.1.2
# Building transformers @ git+https://github.com/huggingface/transformers@0f5e45a6d1ed
# ⠹ Preparing packages... (3/43)
# python-dotenv ------------------------------ 19.40 KiB/19.40 KiB
# jiwer      ------------------------------ 22.49 KiB/22.49 KiB
# audioread  ------------------------------ 22.94 KiB/22.94 KiB
# smmap      ------------------------------ 23.73 KiB/23.73 KiB
# colorama   ------------------------------ 14.84 KiB/24.74 KiB
# gitdb      ------------------------------ 46.91 KiB/61.32 KiB
# pooch      ------------------------------ 46.92 KiB/63.06 KiB
# py7zr      ------------------------------ 62.92 KiB/66.31 KiB
# omegaconf  ------------------------------ 62.85 KiB/77.64 KiB
# evaluate   ------------------------------ 46.91 KiB/82.13 KiB
# dill       ------------------------------ 78.93 KiB/113.53 KiB
KiB
# gitdb      ------------------------------ 46.91 KiB/61.32 KiB
# pooch      ------------------------------ 46.92 KiB/63.06 KiB
# py7zr      ------------------------------ 62.92 KiB/66.31 KiB
# omegaconf  ------------------------------ 62.85 KiB/77.64 KiB
# evaluate   ------------------------------ 46.91 KiB/82.13 KiB
# dill       ------------------------------ 78.93 KiB/113.53 KiB
# multiprocess ------------------------------ 64.00 KiB/143.30 KiB
# hydra-core ------------------------------ 30.84 KiB/150.92 KiB
# gitpython  ------------------------------ 108.17 KiB/203.29 KiB
# librosa    ------------------------------ 96.00 KiB/254.64 KiB
# trl        ------------------------------ 32.00 KiB/306.50 KiB
# sentry-sdk ------------------------------ 46.29 KiB/355.44 KiB
# accelerate ------------------------------ 96.00 KiB/365.94 KiB
# peft       ------------------------------ 62.92 KiB/366.05 KiB
# pyzstd     ------------------------------ 403.91 KiB/403.91 KiB
# Building antlr4-python3-runtime==4.9.3
# Building rouge-score==0.1.2
# Building transformers @ git+https://github.com/huggingface/transformers@0f5e45a6d1ed
# ⠹ Preparing packages... (3/43)
# smmap      ------------------------------ 23.73 KiB/23.73 KiB
# colorama   ------------------------------ 24.74 KiB/24.74 KiB
# gitdb      ------------------------------ 46.91 KiB/61.32 KiB
# pooch      ------------------------------ 62.92 KiB/63.06 KiB
# py7zr      ------------------------------ 66.31 KiB/66.31 KiB
# omegaconf  ------------------------------ 77.64 KiB/77.64 KiB
# evaluate   ------------------------------ 46.91 KiB/82.13 KiB
# dill       ------------------------------ 78.93 KiB/113.53 KiB
# multiprocess ------------------------------ 64.00 KiB/143.30 KiB
# hydra-core ------------------------------ 30.84 KiB/150.92 KiB
# gitpython  ------------------------------ 108.17 KiB/203.29 KiB
# librosa    ------------------------------ 96.00 KiB/254.64 KiB
# trl        ------------------------------ 32.00 KiB/306.50 KiB
# sentry-sdk ------------------------------ 62.29 KiB/355.44 KiB
# accelerate ------------------------------ 128.00 KiB/365.94 KiB
# peft       ------------------------------ 78.92 KiB/366.05 KiB
# pyzstd     ------------------------------ 403.91 KiB/403.91 KiB
# datasets   ------------------------------ 144.00 KiB/469.38 KiB
# Building antlr4-python3-runtime==4.9.3
# Building rouge-score==0.1.2
# Building transformers @ git+https://github.com/huggingface/transformers@0f5e45a6d1ed
# ⠹ Preparing packages... (3/43)
# colorama   ------------------------------ 24.74 KiB/24.74 KiB
# gitdb      ------------------------------ 46.91 KiB/61.32 KiB
# pooch      ------------------------------ 62.92 KiB/63.06 KiB
# py7zr      ------------------------------ 66.31 KiB/66.31 KiB
# omegaconf  ------------------------------ 77.64 KiB/77.64 KiB
# evaluate   ------------------------------ 46.91 KiB/82.13 KiB
# dill       ------------------------------ 78.93 KiB/113.53 KiB
# multiprocess ------------------------------ 64.00 KiB/143.30 KiB
# hydra-core ------------------------------ 30.84 KiB/150.92 KiB
# gitpython  ------------------------------ 108.17 KiB/203.29 KiB
# librosa    ------------------------------ 112.00 KiB/254.64 KiB
# trl        ------------------------------ 48.00 KiB/306.50 KiB
# sentry-sdk ------------------------------ 62.29 KiB/355.44 KiB
# accelerate ------------------------------ 128.00 KiB/365.94 KiB
# peft       ------------------------------ 78.92 KiB/366.05 KiB
# pyzstd     ------------------------------ 403.91 KiB/403.91 KiB
# datasets   ------------------------------ 176.00 KiB/469.38 KiB
# soundfile  ------------------------------ 908.42 KiB/1.25 MiB
# Building antlr4-python3-runtime==4.9.3
# Building rouge-score==0.1.2
# Building transformers @ git+https://github.com/huggingface/transformers@0f5e45a6d1ed
# ⠹ Preparing packages... (3/43)
# colorama   ------------------------------ 24.74 KiB/24.74 KiB
# gitdb      ------------------------------ 46.91 KiB/61.32 KiB
# pooch      ------------------------------ 62.92 KiB/63.06 KiB
# py7zr      ------------------------------ 66.31 KiB/66.31 KiB
# omegaconf  ------------------------------ 77.64 KiB/77.64 KiB
# evaluate   ------------------------------ 46.91 KiB/82.13 KiB
# dill       ------------------------------ 78.93 KiB/113.53 KiB
# multiprocess ------------------------------ 64.00 KiB/143.30 KiB
# hydra-core ------------------------------ 30.84 KiB/150.92 KiB
# gitpython  ------------------------------ 108.17 KiB/203.29 KiB
# librosa    ------------------------------ 112.00 KiB/254.64 KiB
# trl        ------------------------------ 48.00 KiB/306.50 KiB
# sentry-sdk ------------------------------ 62.29 KiB/355.44 KiB
# accelerate ------------------------------ 128.00 KiB/365.94 KiB
# peft       ------------------------------ 78.92 KiB/366.05 KiB
# datasets   ------------------------------ 176.00 KiB/469.38 KiB
# soundfile  ------------------------------ 908.42 KiB/1.25 MiB
# torchcodec ------------------------------ 703.86 KiB/1.31 MiB
# Building antlr4-python3-runtime==4.9.3
# Building rouge-score==0.1.2
# Building transformers @ git+https://github.com/huggingface/transformers@0f5e45a6d1ed
# ⠹ Preparing packages... (3/43)
# colorama   ------------------------------ 24.74 KiB/24.74 KiB
# gitdb      ------------------------------ 46.91 KiB/61.32 KiB
# pooch      ------------------------------ 62.92 KiB/63.06 KiB
# py7zr      ------------------------------ 66.31 KiB/66.31 KiB
# omegaconf  ------------------------------ 77.64 KiB/77.64 KiB
# evaluate   ------------------------------ 46.91 KiB/82.13 KiB
# dill       ------------------------------ 78.93 KiB/113.53 KiB
# multiprocess ------------------------------ 64.00 KiB/143.30 KiB
# hydra-core ------------------------------ 37.30 KiB/150.92 KiB
# gitpython  ------------------------------ 108.17 KiB/203.29 KiB
# librosa    ------------------------------ 112.00 KiB/254.64 KiB
# trl        ------------------------------ 48.00 KiB/306.50 KiB
# sentry-sdk ------------------------------ 62.29 KiB/355.44 KiB
# accelerate ------------------------------ 128.00 KiB/365.94 KiB
# peft       ------------------------------ 78.92 KiB/366.05 KiB
# datasets   ------------------------------ 176.00 KiB/469.38 KiB
# soundfile  ------------------------------ 960.30 KiB/1.25 MiB
# torchcodec ------------------------------ 767.86 KiB/1.31 MiB
# Building antlr4-python3-runtime==4.9.3
# Building rouge-score==0.1.2
# Building transformers @ git+https://github.com/huggingface/transformers@0f5e45a6d1ed
# ⠹ Preparing packages... (3/43)
# gitdb      ------------------------------ 61.32 KiB/61.32 KiB
# pooch      ------------------------------ 62.92 KiB/63.06 KiB
# py7zr      ------------------------------ 66.31 KiB/66.31 KiB
# omegaconf  ------------------------------ 77.64 KiB/77.64 KiB
# evaluate   ------------------------------ 62.91 KiB/82.13 KiB
# dill       ------------------------------ 78.93 KiB/113.53 KiB
# multiprocess ------------------------------ 80.00 KiB/143.30 KiB
# hydra-core ------------------------------ 37.30 KiB/150.92 KiB
# gitpython  ------------------------------ 108.17 KiB/203.29 KiB
# librosa    ------------------------------ 128.00 KiB/254.64 KiB
# trl        ------------------------------ 48.00 KiB/306.50 KiB
# sentry-sdk ------------------------------ 62.29 KiB/355.44 KiB
# accelerate ------------------------------ 128.00 KiB/365.94 KiB
# peft       ------------------------------ 78.92 KiB/366.05 KiB
# datasets   ------------------------------ 187.47 KiB/469.38 KiB
# soundfile  ------------------------------ 1004.42 KiB/1.25 MiB
# torchcodec ------------------------------ 815.86 KiB/1.31 MiB
# nltk       ------------------------------ 140.99 KiB/1.44 MiB
# Building antlr4-python3-runtime==4.9.3
# Building rouge-score==0.1.2
# Building transformers @ git+https://github.com/huggingface/transformers@0f5e45a6d1ed
# ⠹ Preparing packages... (3/43)
# gitdb      ------------------------------ 61.32 KiB/61.32 KiB
# pooch      ------------------------------ 62.92 KiB/63.06 KiB
# omegaconf  ------------------------------ 77.64 KiB/77.64 KiB
# evaluate   ------------------------------ 62.91 KiB/82.13 KiB
# dill       ------------------------------ 78.93 KiB/113.53 KiB
# multiprocess ------------------------------ 80.00 KiB/143.30 KiB
# hydra-core ------------------------------ 37.30 KiB/150.92 KiB
# gitpython  ------------------------------ 108.17 KiB/203.29 KiB
# librosa    ------------------------------ 128.00 KiB/254.64 KiB
# trl        ------------------------------ 48.00 KiB/306.50 KiB
# sentry-sdk ------------------------------ 62.29 KiB/355.44 KiB
# accelerate ------------------------------ 128.00 KiB/365.94 KiB
# peft       ------------------------------ 78.92 KiB/366.05 KiB
# datasets   ------------------------------ 187.47 KiB/469.38 KiB
# soundfile  ------------------------------ 1004.42 KiB/1.25 MiB
# torchcodec ------------------------------ 815.86 KiB/1.31 MiB
# nltk       ------------------------------ 140.99 KiB/1.44 MiB
# pycryptodomex ------------------------------ 30.87 KiB/2.17 MiB
# Building antlr4-python3-runtime==4.9.3
# Building rouge-score==0.1.2
# Building transformers @ git+https://github.com/huggingface/transformers@0f5e45a6d1ed
# ⠹ Preparing packages... (3/43)
# gitdb      ------------------------------ 61.32 KiB/61.32 KiB
# pooch      ------------------------------ 62.92 KiB/63.06 KiB
# omegaconf  ------------------------------ 77.64 KiB/77.64 KiB
# evaluate   ------------------------------ 62.91 KiB/82.13 KiB
# dill       ------------------------------ 78.93 KiB/113.53 KiB
# multiprocess ------------------------------ 80.00 KiB/143.30 KiB
# hydra-core ------------------------------ 53.30 KiB/150.92 KiB
# gitpython  ------------------------------ 140.17 KiB/203.29 KiB
# librosa    ------------------------------ 160.00 KiB/254.64 KiB
# trl        ------------------------------ 64.00 KiB/306.50 KiB
# sentry-sdk ------------------------------ 93.02 KiB/355.44 KiB
# accelerate ------------------------------ 144.00 KiB/365.94 KiB
# peft       ------------------------------ 94.26 KiB/366.05 KiB
# datasets   ------------------------------ 224.00 KiB/469.38 KiB
# soundfile  ------------------------------ 1.18 MiB/1.25 MiB
# torchcodec ------------------------------ 1023.75 KiB/1.31 MiB
# nltk       ------------------------------ 156.99 KiB/1.44 MiB
# pycryptodomex ------------------------------ 64.02 KiB/2.17 MiB
# Building antlr4-python3-runtime==4.9.3
# Building rouge-score==0.1.2
# Building transformers @ git+https://github.com/huggingface/transformers@0f5e45a6d1ed
# ⠹ Preparing packages... (3/43)
# gitdb      ------------------------------ 61.32 KiB/61.32 KiB
# pooch      ------------------------------ 62.92 KiB/63.06 KiB
# evaluate   ------------------------------ 78.91 KiB/82.13 KiB
# dill       ------------------------------ 94.93 KiB/113.53 KiB
# multiprocess ------------------------------ 143.30 KiB/143.30 KiB
# hydra-core ------------------------------ 53.30 KiB/150.92 KiB
# gitpython  ------------------------------ 172.17 KiB/203.29 KiB
# librosa    ------------------------------ 224.00 KiB/254.64 KiB
# trl        ------------------------------ 80.00 KiB/306.50 KiB
# sentry-sdk ------------------------------ 141.02 KiB/355.44 KiB
# accelerate ------------------------------ 160.00 KiB/365.94 KiB
# peft       ------------------------------ 118.86 KiB/366.05 KiB
# datasets   ------------------------------ 224.00 KiB/469.38 KiB
# soundfile  ------------------------------ 1.25 MiB/1.25 MiB
# torchcodec ------------------------------ 1.17 MiB/1.31 MiB
# nltk       ------------------------------ 220.99 KiB/1.44 MiB
# pycryptodomex ------------------------------ 92.36 KiB/2.17 MiB
# brotli     ------------------------------ 1.26 MiB/2.78 MiB
# Building antlr4-python3-runtime==4.9.3
# Building rouge-score==0.1.2
# Building transformers @ git+https://github.com/huggingface/transformers@0f5e45a6d1ed
# ⠹ Preparing packages... (3/43)
# pooch      ------------------------------ 62.92 KiB/63.06 KiB
# evaluate   ------------------------------ 78.91 KiB/82.13 KiB
# dill       ------------------------------ 94.93 KiB/113.53 KiB
# multiprocess ------------------------------ 143.30 KiB/143.30 KiB
# hydra-core ------------------------------ 53.30 KiB/150.92 KiB
# gitpython  ------------------------------ 172.17 KiB/203.29 KiB
# librosa    ------------------------------ 224.00 KiB/254.64 KiB
# trl        ------------------------------ 80.00 KiB/306.50 KiB
# sentry-sdk ------------------------------ 141.02 KiB/355.44 KiB
# accelerate ------------------------------ 160.00 KiB/365.94 KiB
# peft       ------------------------------ 118.86 KiB/366.05 KiB
# datasets   ------------------------------ 224.00 KiB/469.38 KiB
# soundfile  ------------------------------ 1.25 MiB/1.25 MiB
# torchcodec ------------------------------ 1.17 MiB/1.31 MiB
# nltk       ------------------------------ 220.99 KiB/1.44 MiB
# pycryptodomex ------------------------------ 92.36 KiB/2.17 MiB
# brotli     ------------------------------ 1.26 MiB/2.78 MiB
# rapidfuzz  ------------------------------ 1.27 MiB/3.12 MiB
# Building antlr4-python3-runtime==4.9.3
# Building rouge-score==0.1.2
# Building transformers @ git+https://github.com/huggingface/transformers@0f5e45a6d1ed
# ⠹ Preparing packages... (3/43)
# pooch      ------------------------------ 62.92 KiB/63.06 KiB
# evaluate   ------------------------------ 78.91 KiB/82.13 KiB
# dill       ------------------------------ 94.93 KiB/113.53 KiB
# multiprocess ------------------------------ 143.30 KiB/143.30 KiB
# hydra-core ------------------------------ 53.30 KiB/150.92 KiB
# gitpython  ------------------------------ 172.17 KiB/203.29 KiB
# librosa    ------------------------------ 224.00 KiB/254.64 KiB
# trl        ------------------------------ 80.00 KiB/306.50 KiB
# sentry-sdk ------------------------------ 141.02 KiB/355.44 KiB
# accelerate ------------------------------ 160.00 KiB/365.94 KiB
# peft       ------------------------------ 118.86 KiB/366.05 KiB
# datasets   ------------------------------ 224.00 KiB/469.38 KiB
# torchcodec ------------------------------ 1.17 MiB/1.31 MiB
# nltk       ------------------------------ 220.99 KiB/1.44 MiB
# pycryptodomex ------------------------------ 92.36 KiB/2.17 MiB
# brotli     ------------------------------ 1.26 MiB/2.78 MiB
# rapidfuzz  ------------------------------ 1.27 MiB/3.12 MiB
# wandb      ------------------------------ 62.40 KiB/19.10 MiB
# Building antlr4-python3-runtime==4.9.3
# Building rouge-score==0.1.2
# Building transformers @ git+https://github.com/huggingface/transformers@0f5e45a6d1ed
# ⠸ Preparing packages... (19/43)
# pooch      ------------------------------ 62.92 KiB/63.06 KiB
# evaluate   ------------------------------ 78.91 KiB/82.13 KiB
# dill       ------------------------------ 94.93 KiB/113.53 KiB
# multiprocess ------------------------------ 143.30 KiB/143.30 KiB
# hydra-core ------------------------------ 53.30 KiB/150.92 KiB
# gitpython  ------------------------------ 172.17 KiB/203.29 KiB
# librosa    ------------------------------ 224.00 KiB/254.64 KiB
# trl        ------------------------------ 80.00 KiB/306.50 KiB
# sentry-sdk ------------------------------ 141.02 KiB/355.44 KiB
# accelerate ------------------------------ 160.00 KiB/365.94 KiB
# peft       ------------------------------ 118.86 KiB/366.05 KiB
# datasets   ------------------------------ 224.00 KiB/469.38 KiB
# torchcodec ------------------------------ 1.19 MiB/1.31 MiB
# nltk       ------------------------------ 220.99 KiB/1.44 MiB
# pycryptodomex ------------------------------ 92.36 KiB/2.17 MiB
# brotli     ------------------------------ 1.30 MiB/2.78 MiB
# rapidfuzz  ------------------------------ 1.31 MiB/3.12 MiB
# wandb      ------------------------------ 62.40 KiB/19.10 MiB
# Building antlr4-python3-runtime==4.9.3
# Building rouge-score==0.1.2
# Building transformers @ git+https://github.com/huggingface/transformers@0f5e45a6d1ed
# ⠸ Preparing packages... (19/43)
# ...
# Building transformers @ git+https://github.com/huggingface/transformers@0f5e45a6d1ed
# ⠇ Preparing packages... (37/43)
# nltk       ------------------------------ 844.99 KiB/1.44 MiB
# pycryptodomex ------------------------------ 764.36 KiB/2.17 MiB
# wandb      ------------------------------ 15.94 MiB/19.10 MiB
# pyarrow    ------------------------------ 13.30 MiB/40.85 MiB
# Building transformers @ git+https://github.com/huggingface/transformers@0f5e45a6d1ed
# ⠇ Preparing packages... (37/43)
# nltk       ------------------------------ 860.99 KiB/1.44 MiB
# pycryptodomex ------------------------------ 812.36 KiB/2.17 MiB
# wandb      ------------------------------ 16.87 MiB/19.10 MiB
# pyarrow    ------------------------------ 13.84 MiB/40.85 MiB
# Building transformers @ git+https://github.com/huggingface/transformers@0f5e45a6d1ed
# ⠋ Preparing packages... (37/43)
# nltk       ------------------------------ 908.99 KiB/1.44 MiB
# pycryptodomex ------------------------------ 1.45 MiB/2.17 MiB
# wandb      ------------------------------ 17.33 MiB/19.10 MiB
# pyarrow    ------------------------------ 14.92 MiB/40.85 MiB
# Building transformers @ git+https://github.com/huggingface/transformers@0f5e45a6d1ed
# ⠋ Preparing packages... (37/43)
# nltk       ------------------------------ 908.99 KiB/1.44 MiB
# pycryptodomex ------------------------------ 1.51 MiB/2.17 MiB
# wandb      ------------------------------ 17.34 MiB/19.10 MiB
# pyarrow    ------------------------------ 16.43 MiB/40.85 MiB
# Building transformers @ git+https://github.com/huggingface/transformers@0f5e45a6d1ed
# ⠋ Preparing packages... (37/43)
# nltk       ------------------------------ 924.99 KiB/1.44 MiB
# pycryptodomex ------------------------------ 1.51 MiB/2.17 MiB
# wandb      ------------------------------ 17.34 MiB/19.10 MiB
# pyarrow    ------------------------------ 16.79 MiB/40.85 MiB
# Building transformers @ git+https://github.com/huggingface/transformers@0f5e45a6d1ed
# ⠋ Preparing packages... (37/43)
# nltk       ------------------------------ 940.89 KiB/1.44 MiB
# pycryptodomex ------------------------------ 1.62 MiB/2.17 MiB
# wandb      ------------------------------ 17.36 MiB/19.10 MiB
# pyarrow    ------------------------------ 18.08 MiB/40.85 MiB
# Building transformers @ git+https://github.com/huggingface/transformers@0f5e45a6d1ed
# ⠋ Preparing packages... (37/43)
# nltk       ------------------------------ 956.99 KiB/1.44 MiB
# pycryptodomex ------------------------------ 1.62 MiB/2.17 MiB
# wandb      ------------------------------ 17.36 MiB/19.10 MiB
# pyarrow    ------------------------------ 19.44 MiB/40.85 MiB
# Building transformers @ git+https://github.com/huggingface/transformers@0f5e45a6d1ed
# ⠙ Preparing packages... (37/43)
# nltk       ------------------------------ 972.99 KiB/1.44 MiB
# pycryptodomex ------------------------------ 1.71 MiB/2.17 MiB
# wandb      ------------------------------ 17.37 MiB/19.10 MiB
# pyarrow    ------------------------------ 20.64 MiB/40.85 MiB
# Building transformers @ git+https://github.com/huggingface/transformers@0f5e45a6d1ed
# ⠙ Preparing packages... (37/43)
# nltk       ------------------------------ 972.99 KiB/1.44 MiB
# pycryptodomex ------------------------------ 1.77 MiB/2.17 MiB
# wandb      ------------------------------ 17.37 MiB/19.10 MiB
# pyarrow    ------------------------------ 21.81 MiB/40.85 MiB
# Building transformers @ git+https://github.com/huggingface/transformers@0f5e45a6d1ed
# ⠙ Preparing packages... (37/43)
# nltk       ------------------------------ 988.99 KiB/1.44 MiB
# pycryptodomex ------------------------------ 1.85 MiB/2.17 MiB
# wandb      ------------------------------ 17.40 MiB/19.10 MiB
# pyarrow    ------------------------------ 23.05 MiB/40.85 MiB
# Building transformers @ git+https://github.com/huggingface/transformers@0f5e45a6d1ed
# ⠙ Preparing packages... (37/43)
# nltk       ------------------------------ 988.99 KiB/1.44 MiB
# pycryptodomex ------------------------------ 1.85 MiB/2.17 MiB
# wandb      ------------------------------ 17.40 MiB/19.10 MiB
# pyarrow    ------------------------------ 24.00 MiB/40.85 MiB
# Building transformers @ git+https://github.com/huggingface/transformers@0f5e45a6d1ed
# ⠹ Preparing packages... (37/43)
# nltk       ------------------------------ 988.99 KiB/1.44 MiB
# pycryptodomex ------------------------------ 1.85 MiB/2.17 MiB
# wandb      ------------------------------ 17.40 MiB/19.10 MiB
# pyarrow    ------------------------------ 25.37 MiB/40.85 MiB
# Building transformers @ git+https://github.com/huggingface/transformers@0f5e45a6d1ed
# ⠹ Preparing packages... (37/43)
# nltk       ------------------------------ 1.03 MiB/1.44 MiB
# pycryptodomex ------------------------------ 1.90 MiB/2.17 MiB
# wandb      ------------------------------ 17.42 MiB/19.10 MiB
# pyarrow    ------------------------------ 26.87 MiB/40.85 MiB
# Building transformers @ git+https://github.com/huggingface/transformers@0f5e45a6d1ed
# ⠹ Preparing packages... (37/43)
# nltk       ------------------------------ 1.06 MiB/1.44 MiB
# pycryptodomex ------------------------------ 1.95 MiB/2.17 MiB
# wandb      ------------------------------ 17.44 MiB/19.10 MiB
# pyarrow    ------------------------------ 28.26 MiB/40.85 MiB
# Building transformers @ git+https://github.com/huggingface/transformers@0f5e45a6d1ed
# ⠹ Preparing packages... (37/43)
# nltk       ------------------------------ 1.06 MiB/1.44 MiB
# pycryptodomex ------------------------------ 1.95 MiB/2.17 MiB
# wandb      ------------------------------ 17.44 MiB/19.10 MiB
# pyarrow    ------------------------------ 30.15 MiB/40.85 MiB
# Building transformers @ git+https://github.com/huggingface/transformers@0f5e45a6d1ed
# ⠸ Preparing packages... (37/43)
# nltk       ------------------------------ 1.06 MiB/1.44 MiB
# pycryptodomex ------------------------------ 1.95 MiB/2.17 MiB
# wandb      ------------------------------ 17.44 MiB/19.10 MiB
# pyarrow    ------------------------------ 31.24 MiB/40.85 MiB
# Building transformers @ git+https://github.com/huggingface/transformers@0f5e45a6d1ed
# ⠸ Preparing packages... (37/43)
# nltk       ------------------------------ 1.07 MiB/1.44 MiB
# pycryptodomex ------------------------------ 1.98 MiB/2.17 MiB
# wandb      ------------------------------ 17.45 MiB/19.10 MiB
# pyarrow    ------------------------------ 32.98 MiB/40.85 MiB
# Building transformers @ git+https://github.com/huggingface/transformers@0f5e45a6d1ed
# ⠸ Preparing packages... (37/43)
# nltk       ------------------------------ 1.07 MiB/1.44 MiB
# pycryptodomex ------------------------------ 1.98 MiB/2.17 MiB
# wandb      ------------------------------ 17.45 MiB/19.10 MiB
# pyarrow    ------------------------------ 33.65 MiB/40.85 MiB
# Building transformers @ git+https://github.com/huggingface/transformers@0f5e45a6d1ed
# ⠸ Preparing packages... (37/43)
# nltk       ------------------------------ 1.09 MiB/1.44 MiB
# pycryptodomex ------------------------------ 2.00 MiB/2.17 MiB
# wandb      ------------------------------ 17.48 MiB/19.10 MiB
# pyarrow    ------------------------------ 35.30 MiB/40.85 MiB
# Building transformers @ git+https://github.com/huggingface/transformers@0f5e45a6d1ed
# ⠼ Preparing packages... (37/43)
# nltk       ------------------------------ 1.11 MiB/1.44 MiB
# pycryptodomex ------------------------------ 2.00 MiB/2.17 MiB
# wandb      ------------------------------ 17.50 MiB/19.10 MiB
# pyarrow    ------------------------------ 36.47 MiB/40.85 MiB
# Building transformers @ git+https://github.com/huggingface/transformers@0f5e45a6d1ed
# ⠼ Preparing packages... (37/43)
# nltk       ------------------------------ 1.11 MiB/1.44 MiB
# pycryptodomex ------------------------------ 2.00 MiB/2.17 MiB
# wandb      ------------------------------ 17.51 MiB/19.10 MiB
# pyarrow    ------------------------------ 37.79 MiB/40.85 MiB
# Building transformers @ git+https://github.com/huggingface/transformers@0f5e45a6d1ed
# ⠼ Preparing packages... (37/43)
# nltk       ------------------------------ 1.11 MiB/1.44 MiB
# pycryptodomex ------------------------------ 2.00 MiB/2.17 MiB
# wandb      ------------------------------ 17.54 MiB/19.10 MiB
# pyarrow    ------------------------------ 38.78 MiB/40.85 MiB
# Building transformers @ git+https://github.com/huggingface/transformers@0f5e45a6d1ed
# ⠼ Preparing packages... (37/43)
# nltk       ------------------------------ 1.13 MiB/1.44 MiB
# pycryptodomex ------------------------------ 2.02 MiB/2.17 MiB
# wandb      ------------------------------ 17.58 MiB/19.10 MiB
# pyarrow    ------------------------------ 38.81 MiB/40.85 MiB
# Building transformers @ git+https://github.com/huggingface/transformers@0f5e45a6d1ed
# ⠴ Preparing packages... (37/43)
# nltk       ------------------------------ 1.15 MiB/1.44 MiB
# pycryptodomex ------------------------------ 2.04 MiB/2.17 MiB
# wandb      ------------------------------ 17.62 MiB/19.10 MiB
# pyarrow    ------------------------------ 38.89 MiB/40.85 MiB
# Building transformers @ git+https://github.com/huggingface/transformers@0f5e45a6d1ed
# ⠴ Preparing packages... (37/43)
# nltk       ------------------------------ 1.15 MiB/1.44 MiB
# pycryptodomex ------------------------------ 2.05 MiB/2.17 MiB
# wandb      ------------------------------ 17.64 MiB/19.10 MiB
# pyarrow    ------------------------------ 38.89 MiB/40.85 MiB
# Building transformers @ git+https://github.com/huggingface/transformers@0f5e45a6d1ed
# ⠴ Preparing packages... (37/43)
# nltk       ------------------------------ 1.16 MiB/1.44 MiB
# pycryptodomex ------------------------------ 2.07 MiB/2.17 MiB
# wandb      ------------------------------ 17.65 MiB/19.10 MiB
# pyarrow    ------------------------------ 38.91 MiB/40.85 MiB
# Building transformers @ git+https://github.com/huggingface/transformers@0f5e45a6d1ed
# ⠴ Preparing packages... (37/43)
# nltk       ------------------------------ 1.16 MiB/1.44 MiB
# pycryptodomex ------------------------------ 2.10 MiB/2.17 MiB
# wandb      ------------------------------ 17.67 MiB/19.10 MiB
# pyarrow    ------------------------------ 38.92 MiB/40.85 MiB
# Building transformers @ git+https://github.com/huggingface/transformers@0f5e45a6d1ed
# ⠦ Preparing packages... (37/43)
# nltk       ------------------------------ 1.16 MiB/1.44 MiB
# pycryptodomex ------------------------------ 2.11 MiB/2.17 MiB
# wandb      ------------------------------ 17.70 MiB/19.10 MiB
# pyarrow    ------------------------------ 38.94 MiB/40.85 MiB
# Building transformers @ git+https://github.com/huggingface/transformers@0f5e45a6d1ed
# ⠦ Preparing packages... (37/43)
# nltk       ------------------------------ 1.18 MiB/1.44 MiB
# pycryptodomex ------------------------------ 2.13 MiB/2.17 MiB
# wandb      ------------------------------ 17.75 MiB/19.10 MiB
# pyarrow    ------------------------------ 38.98 MiB/40.85 MiB
# Building transformers @ git+https://github.com/huggingface/transformers@0f5e45a6d1ed
# ⠦ Preparing packages... (37/43)
# nltk       ------------------------------ 1.21 MiB/1.44 MiB
# pycryptodomex ------------------------------ 2.16 MiB/2.17 MiB
# wandb      ------------------------------ 17.83 MiB/19.10 MiB
# pyarrow    ------------------------------ 39.03 MiB/40.85 MiB
# Building transformers @ git+https://github.com/huggingface/transformers@0f5e45a6d1ed
# ⠦ Preparing packages... (37/43)
# nltk       ------------------------------ 1.31 MiB/1.44 MiB
# wandb      ------------------------------ 17.98 MiB/19.10 MiB
# pyarrow    ------------------------------ 39.11 MiB/40.85 MiB
# Building transformers @ git+https://github.com/huggingface/transformers@0f5e45a6d1ed
# ⠦ Preparing packages... (37/43)
# nltk       ------------------------------ 1.34 MiB/1.44 MiB
# wandb      ------------------------------ 18.03 MiB/19.10 MiB
# Building transformers @ git+https://github.com/huggingface/transformers@0f5e45a6d1ed
# ⠦ Preparing packages... (37/43)
# wandb      ------------------------------ 18.12 MiB/19.10 MiB
# Building transformers @ git+https://github.com/huggingface/transformers@0f5e45a6d1ed
# ⠦ Preparing packages... (37/43)
# wandb      ------------------------------ 18.14 MiB/19.10 MiB
# Building transformers @ git+https://github.com/huggingface/transformers@0f5e45a6d1ed
# ⠧ Preparing packages... (40/43)
# wandb      ------------------------------ 18.34 MiB/19.10 MiB
# Building transformers @ git+https://github.com/huggingface/transformers@0f5e45a6d1ed
# ⠧ Preparing packages... (40/43)
# wandb      ------------------------------ 18.73 MiB/19.10 MiB
# Building transformers @ git+https://github.com/huggingface/transformers@0f5e45a6d1ed
# ⠧ Preparing packages... (40/43)
# Building transformers @ git+https://github.com/huggingface/transformers@0f5e45a6d1ed
# ⠧ Preparing packages... (40/43)
# Building transformers @ git+https://github.com/huggingface/transformers@0f5e45a6d1ed
# Building transformers @ git+https://github.com/huggingface/transformers@0f5e45a6d1ed
# Building transformers @ git+https://github.com/huggingface/transformers@0f5e45a6d1ed
# Building transformers @ git+https://github.com/huggingface/transformers@0f5e45a6d1ed
# Building transformers @ git+https://github.com/huggingface/transformers@0f5e45a6d1ed
# Building transformers @ git+https://github.com/huggingface/transformers@0f5e45a6d1ed
# Building transformers @ git+https://github.com/huggingface/transformers@0f5e45a6d1ed
# Building transformers @ git+https://github.com/huggingface/transformers@0f5e45a6d1ed
# Building transformers @ git+https://github.com/huggingface/transformers@0f5e45a6d1ed
# Building transformers @ git+https://github.com/huggingface/transformers@0f5e45a6d1ed
# Building transformers @ git+https://github.com/huggingface/transformers@0f5e45a6d1ed
# Building transformers @ git+https://github.com/huggingface/transformers@0f5e45a6d1ed
# Building transformers @ git+https://github.com/huggingface/transformers@0f5e45a6d1ed
# Building transformers @ git+https://github.com/huggingface/transformers@0f5e45a6d1ed
# Building transformers @ git+https://github.com/huggingface/transformers@0f5e45a6d1ed
# Building transformers @ git+https://github.com/huggingface/transformers@0f5e45a6d1ed
# Building transformers @ git+https://github.com/huggingface/transformers@0f5e45a6d1ed
# Building transformers @ git+https://github.com/huggingface/transformers@0f5e45a6d1ed
# Building transformers @ git+https://github.com/huggingface/transformers@0f5e45a6d1ed
# Building transformers @ git+https://github.com/huggingface/transformers@0f5e45a6d1ed
# Building transformers @ git+https://github.com/huggingface/transformers@0f5e45a6d1ed
# Building transformers @ git+https://github.com/huggingface/transformers@0f5e45a6d1ed
# Building transformers @ git+https://github.com/huggingface/transformers@0f5e45a6d1ed
# Building transformers @ git+https://github.com/huggingface/transformers@0f5e45a6d1ed
# Building transformers @ git+https://github.com/huggingface/transformers@0f5e45a6d1ed
# Building transformers @ git+https://github.com/huggingface/transformers@0f5e45a6d1ed
#    Built transformers @ git+https://github.com/huggingface/transformers@0f5e45a6d1ed
# Prepared 43 packages in 8.82s
# Uninstalled 4 packages in 708ms
# Installed 43 packages in 422ms
#  - accelerate==1.10.1
#  + accelerate==1.10.0
#  + antlr4-python3-runtime==4.9.3
#  + audioread==3.0.1
#  + bitsandbytes==0.47.0
#  + brotli==1.1.0
#  + colorama==0.4.6
#  + datasets==3.2.0
#  + dill==0.3.8
#  + docker-pycreds==0.4.0
#  + evaluate==0.4.5
#  + gitdb==4.0.12
#  + gitpython==3.1.45
#  + hydra-core==1.3.2
#  + inflate64==1.0.3
#  + jiwer==4.0.0
#  + librosa==0.11.0
#  + multiprocess==0.70.16
#  + multivolumefile==0.2.3
#  + nltk==3.9.1
#  + omegaconf==2.3.0
#  + peft==0.14.0
#  + pooch==1.8.2
#  + py7zr==0.22.0
#  + pyarrow==21.0.0
#  + pybcj==1.0.6
#  + pycryptodomex==3.23.0
#  + pyppmd==1.1.1
#  - python-dotenv==1.1.1
#  + python-dotenv==1.0.1
#  + pyzstd==0.17.0
#  + rapidfuzz==3.14.0
#  + rouge-score==0.1.2
#  + sentry-sdk==2.35.2
#  + setproctitle==1.3.6
#  + smmap==5.0.2
#  + soundfile==0.13.1
#  + soxr==0.5.0.post1
#  + texttable==1.7.0
#  + torchcodec==0.6.0
#  - transformers==4.56.0
#  + transformers==4.57.0.dev0 (from git+https://github.com/huggingface/transformers@0f5e45a6d1ed40862cf37610a3c59694c822a07b)
#  + trl==0.14.0
#  - typing-extensions==4.12.2
#  + typing-extensions==4.15.0
#  + wandb==0.19.1
#  + xxhash==3.5.0
# Note: you may need to restart the kernel to use updated packages.

# %%
ls configs/
# Out:
# 03092025/        phowhisper-base.yaml                whisper-base.yaml
# 28082025/        quan_whisper-base__vietbud500.yaml  whisper-base_ft.yaml
# eraxai_wow.yaml  transcribe.yaml

# %%
ls configs/03092025
# Out:
# openai_whisper-large-v3-turbo__vimd.yaml

# %%
from src.utils.exp_utils import print_cfg

# %%
print_cfg("configs/28082025/openai_whisper-large-v3-turbo__lsvsc.yaml")
# Out:
# exp_manager:
#   prj_name: vnpost_asr_ft
#   exp_name: openai_whisper-large-v3-turbo__lsvsc
#   exp_variant: wo_ft
#   exp_notes: 'data preprocess: filter outaudio, labels with length exceed; donot preprocess
#     text for training'
#   seed: 202508
#   task_name: vi_asr
#   dataset_name: null
#   model_name: openai/whisper-large-v3-turbo
#   phase_name: eval
#   print_cfg: true
#   exps_dir: exps
#   print_model: true
#   print_processor: false
#   print_trainable_parameters: true
#   print_parameter_datatypes: true
#   print_peft_config: true
#   print_device: true
#   print_training_args: false
#   wandb:
#     project: vnpost_asr_ft
#     log_artifact: false
# data:
#   is_prepared: true
#   prepared_data_dir: null
#   root_data_dir: /mnt/data-vol/vnpost-asr/LSVSC
#   streaming: false
#   columns_to_retain:
#   - sample_id
#   - audio
#   - text
#   - filename
#   subset_ratio: 1
#   do_save: true
#   do_show: false
#   prepared_data_dirname: prepared_data
# model:
#   model_type: ASR
#   pretrained_model_name_or_path: openai/whisper-large-v3-turbo
#   pretrained_processor_name_or_path: null
#   load_in_4bit: false
#   load_in_8bit: false
#   bnb_4bit_compute_dtype: null
#   bnb_4bit_quant_type: nf4
#   bnb_4bit_use_double_quant: false
#   bnb_4bit_quant_storage: uint8
#   torch_dtype: float16
#   attn_implementation: null
#   device_map: null
#   low_cpu_mem_usage: null
#   adapter_path: null
# train:
#   use_peft: false
#   lora:
#     r: 32
#     lora_alpha: 64
#     lora_dropout: 0.0
#     bias: none
#     task_type: null
#     inference_mode: false
#     target_modules:
#     - q_proj
#     - k_proj
#     - v_proj
#     - o_proj
#     - gate_proj
#     - up_proj
#     - down_proj
#     modules_to_save: []
#   merge_after_train: true
#   train_n_samples: -1
#   val_n_samples: 128
#   test_n_samples: 128
#   do_resume_from_checkpoint: false
#   train_metric_filename: train_metrics.json
#   eval_metrics:
#   - wer
#   train_args:
#     _target_: transformers.Seq2SeqTrainingArguments
#     resume_from_checkpoint: null
#     do_train: true
#     do_eval: true
#     do_predict: false
#     learning_rate: 5.0e-05
#     warmup_steps: 500
#     num_train_epochs: 1
#     per_device_train_batch_size: 128
#     per_device_eval_batch_size: 192
#     logging_steps: 1
#     logging_first_step: true
#     save_strategy: epoch
#     eval_strategy: steps
#     eval_steps: 10
#     eval_accumulation_steps: 1
#     eval_on_start: true
#     use_cpu: false
#     report_to: None
#     remove_unused_columns: false
# generate:
#   max_new_tokens: 256
#   pad_token_id: null
#   skip_special_tokens: true
#   temperature: null
#   do_sample: null
# evaluate:
#   batch_size: 128
#   break_step: -1
#   do_extract_prediction: true
#   metric_filename: test_metrics.txt
#   prediction_filename: test_predictions.txt
#   result_filename: test_result.txt
# device:
#   use_cpu: false

# %%
# !python prepare_data.py  \
#     --config_path=configs/03092025/openai_whisper-large-v3-turbo__vimd.yaml \
#     exp_manager.exp_variant="label_text_normalized"

# %%
# !python eval.py  \
    --config_path=configs/03092025/openai_whisper-large-v3-turbo__vimd.yaml \
    exp_manager.exp_variant="label_text_normalized" \
    evaluate.break_step=1 \
    evaluate.batch_size=1
