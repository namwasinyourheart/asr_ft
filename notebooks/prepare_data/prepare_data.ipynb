# %%
cd /home/nampv1/projects/vnpost_asr/
# Out:
# /home/nampv1/projects/vnpost_asr

# %%
from src.utils.exp_utils import print_cfg

# %%
print_cfg("/home/nampv1/projects/vnpost_asr/configs/15092025/merged_ds_openai_whisper-large-v3-turbo.yaml")
# Out:
# exp_manager:
#   prj_name: vnpost_asr_ft
#   exp_name: merge_ds_openai_whisper-large-v3-turbo
#   exp_variant: toy
#   exp_notes: vlsp2020, vivos, commonvoice_vi_21, vimd, lsvsc, fleurs, fpt_fosd, infore1_25hours
#   seed: 202508
#   task_name: vi_asr
#   dataset_name: null
#   model_name: openai/whisper-large-v3-turbo
#   phase_name: eval
#   print_cfg: true
#   exps_dir: exps
#   print_model: true
#   print_processor: false
#   print_trainable_parameters: true
#   print_parameter_datatypes: true
#   print_peft_config: true
#   print_device: true
#   print_training_args: false
#   exp_tracking_tool: wandb
#   wandb:
#     project: vnpost_asr_ft
#     log_artifact: false
# data:
#   continue_prep: true
#   prepared_data_dir: ''
#   root_data_dir: /media/nampv1/hdd/data/merged_hfds
#   hf_raw_data_dir: /media/nampv1/hdd/data/merged_hfds/raw/hf
#   do_merge: true
#   datasets:
#   - name: vimd
#     hf_raw_data_dir: /media/nampv1/hdd/data/vnpost-asr/ViMD/raw
# ...

# %%
ls /media/nampv1/hdd/data/merged_vivos_vlsp2020_commonvoice_22_vi/exps
# Out:
# merge_ds_openai_whisper-large-v3-turbo__toy/

# %%
# !ls /media/nampv1/hdd/data/merged_vivos_vlsp2020_commonvoice_22_vi/exps/merge_ds_openai_whisper-large-v3-turbo__toy
# !rm -r /media/nampv1/hdd/data/merged_ds/exps/merge_ds_openai_whisper-large-v3-turbo__toy
# !rm -r /media/nampv1/hdd/data/merged_ds/processed

# %%
# !python prepare_data.py \
    --config_path="configs/15092025/merged_ds_openai_whisper-large-v3-turbo.yaml" \
# Out:
# exp_manager:
#   prj_name: vnpost_asr_ft
#   exp_name: merge_ds_openai_whisper-large-v3-turbo
#   exp_variant: toy
#   exp_notes: vlsp2020, vivos, commonvoice_vi_21, vimd, lsvsc, fleurs, fpt_fosd, infore1_25hours
#   seed: 202508
#   task_name: vi_asr
#   dataset_name: null
#   model_name: openai/whisper-large-v3-turbo
#   phase_name: eval
#   print_cfg: true
#   exps_dir: exps
#   print_model: true
#   print_processor: false
#   print_trainable_parameters: true
#   print_parameter_datatypes: true
#   print_peft_config: true
#   print_device: true
#   print_training_args: false
#   exp_tracking_tool: wandb
#   wandb:
#     project: vnpost_asr_ft
#     log_artifact: false
# data:
#   continue_prep: true
#   prepared_data_dir: ''
#   root_data_dir: /media/nampv1/hdd/data/merged_ds
#   hf_raw_data_dir: /media/nampv1/hdd/data/merged_ds/raw/hf
#   do_merge: true
#   datasets:
#   - name: vimd
#     hf_raw_data_dir: /media/nampv1/hdd/data/vnpost-asr/ViMD/raw
#     use_existing_hfds: true
# ...

# %%
from datasets import load_from_disk

# %%
merged_ds = load_from_disk("/media/nampv1/hdd/data/merged_ds/exps/merge_ds_openai_whisper-large-v3-turbo__toy")

# %%
merged_ds['train'][0]
# Out:
# {'sample_id': 'vimd_0',
#  'filename': '36_0213.wav',
#  'input_features': [[-0.27795135974884033,
#    0.1313842535018921,
#    0.26241016387939453,
#    0.3070489764213562,
#    0.32160431146621704,
#    0.14507842063903809,
#    0.20533329248428345,
#    0.33552902936935425,
#    0.2954784631729126,
#    0.5125381350517273,
#    0.11801284551620483,
#    0.21824872493743896,
#    0.2656761407852173,
#    0.2091602087020874,
#    0.2032794952392578,
#    0.13335782289505005,
#    -0.052939772605895996,
#    -0.2050492763519287,
#    0.05954146385192871,
#    0.07013797760009766,
#    0.018139421939849854,
#    -0.09764814376831055,
#    0.24415403604507446,
#    0.19432532787322998,
#    -0.05127584934234619,
#    0.03997749090194702,
#    0.20778608322143555,
#    0.25989747047424316,
#    0.22258538007736206,
#    0.3274046778678894,
#    0.37232309579849243,
#    0.24038875102996826,
#    0.30400413274765015,
#    0.35874587297439575,
#    0.39403754472732544,
# ...
