# %%
cd /home/nampv1/projects/vnpost_asr/
# Out:
# /home/nampv1/projects/vnpost_asr

# %%
raw_data_dir = "/media/nampv1/hdd/data/ASR-CommonVoice22Vi-21H/raw/cv-corpus-22.0-2025-06-20/vi"

# %%
from src.utils.utils import tree_str

# %%
print(tree_str(raw_data_dir, max_files=10))
# Out:
# vi/
# ├── clips/
# │   ├── common_voice_vi_21824030.mp3
# │   ├── common_voice_vi_21824031.mp3
# │   ├── common_voice_vi_21824032.mp3
# │   ├── common_voice_vi_21824033.mp3
# │   ├── common_voice_vi_21824034.mp3
# │   ├── common_voice_vi_21824045.mp3
# │   ├── common_voice_vi_21824046.mp3
# │   ├── common_voice_vi_21824047.mp3
# │   ├── common_voice_vi_21824048.mp3
# │   ├── common_voice_vi_21824049.mp3
# │   └── ... 18751 more files
# ├── clip_durations.tsv
# ├── dev.tsv
# ├── invalidated.tsv
# ├── other.tsv
# ├── reported.tsv
# ├── test.tsv
# ├── train.tsv
# ├── unvalidated_sentences.tsv
# ├── validated.tsv
# └── validated_sentences.tsv

# %%
pwd
# Out:
# '/home/nampv1/projects/vnpost_asr'

# %%
dataset_source_dir = "/media/nampv1/hdd/data/ASR-CommonVoice22Vi-21H/raw/cv-corpus-22.0-2025-06-20/vi"

# %%
ls /home/nampv1/projects/vnpost_asr/prepare_data/commonvoice_22_vi_hfds
# Out:
# commonvoice_22_vi.py  __init__.py

# %%
from datasets import load_dataset

dataset = load_dataset(
    "prepare_data/commonvoice_22_vi_hfds/commonvoice_22_vi.py", 
    data_dir=dataset_source_dir,
    trust_remote_code=True
)

print(dataset)
# Out:
# Generating train split: 2104 examples [00:00, 33851.37 examples/s]
# Generating test split: 1014 examples [00:00, 35561.59 examples/s]
# Generating validation split: 931 examples [00:00, 34108.07 examples/s]
# DatasetDict({
#     train: Dataset({
#         features: ['sample_id', 'audio', 'filename', 'text', 'gender', 'accents'],
#         num_rows: 2104
#     })
#     test: Dataset({
#         features: ['sample_id', 'audio', 'filename', 'text', 'gender', 'accents'],
#         num_rows: 1014
#     })
#     validation: Dataset({
#         features: ['sample_id', 'audio', 'filename', 'text', 'gender', 'accents'],
#         num_rows: 931
#     })
# })

# %%
dataset['test'][1000]
# Out:
# {'sample_id': 1000,
#  'audio': {'path': '/media/nampv1/hdd/data/ASR-CommonVoice22Vi-21H/raw/cv-corpus-22.0-2025-06-20/vi/clips/common_voice_vi_22417055.mp3',
#   'array': array([ 0.00000000e+00,  6.82884061e-15,  2.54718969e-14, ...,
#          -4.05359697e-06, -1.35685186e-05, -1.01100741e-05], shape=(196992,)),
#   'sampling_rate': 48000},
#  'filename': 'common_voice_vi_22417055.mp3',
#  'text': 'Họp lớp sau nhiều năm Mỗi Người Một Nơi',
#  'gender': 'male_masculine',
#  'accents': ''}
